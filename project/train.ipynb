# %%
# from google.colab import drive

# drive.mount("/content/drive")

# %%
# import sys

# path = "/content/drive/MyDrive/IC"
# sys.path.append(path)

# %%
path = "/home/misael/Documents/IC"

# %%
data_path = path + "/data"
model_path = path + "/model"

# %%
set = "augmented"
batch_size = 1000

# %%
from dataset import get_dataset

mnist = get_dataset(data_path, "mnist")

# %%
from dataset import plot_batch

dataset = get_dataset(data_path, set)
plot_batch(dataset, batch_size)

# %%
from model import Model

model = Model()

# %%
from trainer import train_model

train_model(27, model, dataset, mnist["val"], model_path, 0.007)
